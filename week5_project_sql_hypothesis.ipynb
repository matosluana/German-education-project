# %%
import pandas as pd
import numpy as np

import pymysql      
from sqlalchemy import create_engine
from getpass import getpass
from scipy.stats import ttest_1samp

# %%
# password = getpass()
# Out:
# ········

# %%
connection_string = 'mysql+pymysql://root:'+password+'@localhost/midproject_education_germany'
engine = create_engine(connection_string)
data = pd.read_sql_query('SELECT * FROM frankfurt_city', engine)
data.head()
# Out:
#      neighbourhood  inhabitants  average_age  \
# 0         Altstadt         4255         42.4
# 1       Innenstadt         6550         41.4
# 2  Bahnhofsviertel         3703         37.7
# 3      Westend-Süd        19318         40.3
# 4     Westend-Nord        10330         39.1
#
#    inhabitants_up_to_17_years_in_%.  inhabitants_from_18_to_64_years_in_%.  \
# 0                         11.891892                              72.502938
# 1                          8.870229                              76.870229
# 2                          8.209560                              84.904132
# 3                         15.824620                              69.650067
# 4                         16.379477                              69.060987
#
#    inhabitants_from_65_years_in_%  foreigners_in_%  \
# 0                       15.605170        36.451234
# 1                       14.259542        45.541985
# 2                        6.886308        49.986497
# ...

# %%
data.columns
# Out:
# Index(['neighbourhood', 'inhabitants', 'average_age',
#        'inhabitants_up_to_17_years_in_%.',
#        'inhabitants_from_18_to_64_years_in_%.',
#        'inhabitants_from_65_years_in_%', 'foreigners_in_%',
#        'germans_with_migration_background_in_%',
#        'germans_without_migration_background_in_%',
#        'population_development_(5-year_comparison)', 'households',
#        'single-person_households_in_%', 'families_with_children_in_%',
#        'pupils_at_general_education_schools',
#        'proportion_of_students_transferring_to_gymnasium',
#        'employment_density', 'unemployment_density', 'social_benefits',
#        'total_households', 'until_1000€', 'over_1000_until_3000€',
#        'over_3000_until_5000€', 'over_5000€', 'median_income_€'],
#       dtype='object')

# %%
# I will keep only the columns I need for my testing
data = data.drop(columns=['average_age',
       'inhabitants_up_to_17_years_in_%.',
       'inhabitants_from_18_to_64_years_in_%.','unemployment_density','social_benefits','employment_density',
       'inhabitants_from_65_years_in_%','population_development_(5-year_comparison)', 'households',
       'single-person_households_in_%', 'families_with_children_in_%','total_households', 'until_1000€', 'over_1000_until_3000€',
       'over_3000_until_5000€', 'over_5000€',
       'pupils_at_general_education_schools',])

data
# Out:
#          neighbourhood  inhabitants  foreigners_in_%  \
# 0             Altstadt         4255        36.451234
# 1           Innenstadt         6550        45.541985
# 2      Bahnhofsviertel         3703        49.986497
# 3          Westend-Süd        19318        27.290610
# 4         Westend-Nord        10330        28.789932
# 5         Nordend-West        30975        21.352704
# 6          Nordend-Ost        23135        22.260644
# 7               Ostend        29704        28.534877
# 8             Bornheim        30761        23.776860
# 9       Gutleutviertel         6786        42.381373
# 10              Gallus        42012        40.636009
# 11          Bockenheim        42140        33.151400
# 12  Sachsenhausen-Nord        32824        24.549110
# 13   Sachsenhausen-Süd        29163        24.270480
# 14             Oberrad        13648        33.733880
# 15           Niederrad        27043        36.242281
# 16          Schwanheim        20576        24.616058
# ...

# %%
data =data[data['proportion_of_students_transferring_to_gymnasium'] !=0]
data
# Out:
#          neighbourhood  inhabitants  foreigners_in_%  \
# 1           Innenstadt         6550        45.541985
# 2      Bahnhofsviertel         3703        49.986497
# 3          Westend-Süd        19318        27.290610
# 4         Westend-Nord        10330        28.789932
# 5         Nordend-West        30975        21.352704
# 6          Nordend-Ost        23135        22.260644
# 7               Ostend        29704        28.534877
# 8             Bornheim        30761        23.776860
# 10              Gallus        42012        40.636009
# 11          Bockenheim        42140        33.151400
# 12  Sachsenhausen-Nord        32824        24.549110
# 13   Sachsenhausen-Süd        29163        24.270480
# 14             Oberrad        13648        33.733880
# 15           Niederrad        27043        36.242281
# 16          Schwanheim        20576        24.616058
# 17           Griesheim        23569        42.292842
# 18           Rödelheim        19253        33.729808
# ...

# %%
#creating income bins

def income_bin(income):
    if income <=2000:
        return 'very low'
    elif income >2000 and income <=2750:
        return 'low'
    elif income >2750 and income <=3500:
        return 'medium'
    elif income >3500 and income <4250:
        return 'high'
    elif income >4250:
        return 'very high'
    

data['income_bin']= data['median_income_€'].apply(income_bin)
data
# Out:
# C:\Users\luana\AppData\Local\Temp\ipykernel_28288\3912492809.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['income_bin']= data['median_income_€'].apply(income_bin)
#          neighbourhood  inhabitants  foreigners_in_%  \
# 1           Innenstadt         6550        45.541985
# 2      Bahnhofsviertel         3703        49.986497
# 3          Westend-Süd        19318        27.290610
# 4         Westend-Nord        10330        28.789932
# 5         Nordend-West        30975        21.352704
# 6          Nordend-Ost        23135        22.260644
# 7               Ostend        29704        28.534877
# 8             Bornheim        30761        23.776860
# 10              Gallus        42012        40.636009
# ...

# %% [markdown]
# ### Hypothesis testing only for the very high incomes

# %%
# H0 = very high income acceptance rates <= other incomes acceptance rates 
# H1 = very high income acceptance rates > other incomes acceptance rates

data_very_high_income = data[data['income_bin'] == 'very high']
data_very_high_income
# Out:
#          neighbourhood  inhabitants  foreigners_in_%  \
# 3          Westend-Süd        19318        27.290610
# 4         Westend-Nord        10330        28.789932
# 5         Nordend-West        30975        21.352704
# 12  Sachsenhausen-Nord        32824        24.549110
# 40    Kalbach-Riedberg        22170        23.635544
# 44    Frankfurter Berg         8225        27.343465
#
#     germans_with_migration_background_in_%  \
# 3                                19.846775
# 4                                24.646660
# 5                                18.673123
# 12                               21.085182
# 40                               29.801534
# 44                               31.671733
#
#     germans_without_migration_background_in_%  \
# 3                                   52.862615
# 4                                   46.563408
# 5                                   59.974173
# 12                                  54.365708
# ...

# %%
data_without_very_high = data[data['income_bin'] != 'very high']
median_without_very_high = np.median(data_without_very_high['proportion_of_students_transferring_to_gymnasium'])
median_without_very_high
# Out:
# 47.5

# %%
stat, pval = ttest_1samp(data_very_high_income['proportion_of_students_transferring_to_gymnasium'], median_without_very_high)

# %%
print('stat is  ', stat)
print('pvalue for the two-tailed test is ', pval)

print('pvalue for the one-tailed test is ', pval/2)
# Out:
# stat is   4.527966905506897
# pvalue for the two-tailed test is  0.006237106983243337
# pvalue for the one-tailed test is  0.0031185534916216683

# %% [markdown]
# <b> H0 = higher income acceptance rates <= lower incomes acceptance rates</b>
#
# Can be discarded, since pvalues <0.05 and stat is positive
#
#
# <b> H1 = higher income acceptance rates > lower incomes acceptance rates</b>
#
# Accepted because stat is positive

# %% [markdown]
# ### Hypothesis testing for high incomes against low and medium incomes

# %%
# H0 = high income acceptance rates <= low and medium incomes acceptance rates 
# H1 = high income acceptance rates acceptance rates > low and medium acceptance rates

data_high_income = data[data['income_bin'] == 'high']
data_high_income
# Out:
#         neighbourhood  inhabitants  foreigners_in_%  \
# 6         Nordend-Ost        23135        22.260644
# 7              Ostend        29704        28.534877
# 8            Bornheim        30761        23.776860
# 11         Bockenheim        42140        33.151400
# 13  Sachsenhausen-Süd        29163        24.270480
# 24          Dornbusch        18715        22.249532
# 25        Eschersheim        15323        21.829929
# 39   Nieder-Erlenbach         4686        13.764405
# 41            Harheim         5294        16.150359
# 43     Bergen-Enkheim        17988        20.102290
# 45  Frankfurt am Main       758847        29.977848
#
#     germans_with_migration_background_in_%  \
# 6                                18.517398
# 7                                21.535820
# 8                                22.232697
# 11                               22.289986
# 13                               20.916915
# 24                               23.964734
# ...

# %%
data_medium_low_income = data[data['income_bin'] != 'high']
data_medium_low_income = data_medium_low_income[data_medium_low_income['income_bin'] != 'high']

median_medium_low_income = np.median(data_medium_low_income['proportion_of_students_transferring_to_gymnasium'])
median_medium_low_income
# Out:
# 44.400000000000006

# %%
stat, pval = ttest_1samp(data_high_income['proportion_of_students_transferring_to_gymnasium'], median_medium_low_income)

# %%
print('stat is  ', stat)
print('pvalue for the two-tailed test is ', pval)

print('pvalue for the one-tailed test is ', pval/2)
# Out:
# stat is   6.314194446414951
# pvalue for the two-tailed test is  8.746440513611495e-05
# pvalue for the one-tailed test is  4.3732202568057476e-05

# %% [markdown]
# <b>H0 = high income acceptance rates <= low and medium incomes acceptance rates
#
# <b> H1 = high income acceptance rates acceptance rates > low and medium acceptance rates</b>
#
# H1 is accepted. There is a high probability that more students from neghbourhoods with higher income will be transferred to Gymnasium in comparison with lower income neighbourhoods.
